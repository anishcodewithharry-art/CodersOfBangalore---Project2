# %%
with open("finaldata.txt", encoding='utf-8') as file:
    data = file.read()

# %%
data
# Out:
# "techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes\n\nblrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes\n\nhsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com\n\ncloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud\n\nkoramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter\n\nai_bangalore_news\n1,340 posts\n38K followers\n200 following\nAI Bangalore\nMedia\n🤖 Daily AI news from India\n📢 Startup & resea
# ...

# %%
chunks = data.split("\n\n")
chunks = [c for c in chunks if len(c)>3]

# %%
chunks[5]
# Out:
# 'ai_bangalore_news\n1,340 posts\n38K followers\n200 following\nAI Bangalore\nMedia\n🤖 Daily AI news from India\n📢 Startup & research updates\naibanglore.ai/news'

# %%
# Function to parse the chunks one-by-one
def parse_chunk(chunk):
    try:
        chunk = chunk.strip()
        splitted_chunk= chunk.split("\n")
    
        username = splitted_chunk[0]
        no_of_posts = int(splitted_chunk[1].split(" post")[0].replace(",", ""))
        no_of_followers = float(splitted_chunk[2].split(" followers")[0].replace(",", "").replace("K", "").replace("M", ""))

        if "K" in splitted_chunk[2].split(" followers")[0]:
            no_of_followers = int(no_of_followers * 1000)
        elif "M" in splitted_chunk[2].split(" followers")[0]:
            no_of_followers = int(no_of_followers * 1000000)
        else:
            no_of_followers = int(no_of_followers)
            
        # no_of_following = int(splitted_chunk[3].split(" following")[0].replace(",", ""))

        no_of_following = float(splitted_chunk[3].split(" following")[0].replace(",", "").replace("K", "").replace("M", ""))

        if "K" in splitted_chunk[3].split(" following")[0]:
            no_of_following = int(no_of_following * 1000)
        elif "M" in splitted_chunk[3].split(" following")[0]:
            no_of_following = int(no_of_following * 1000000)
        else:
            no_of_following = int(no_of_following)
        
        name = splitted_chunk[4]

        if (len(splitted_chunk)>5):
            type_of_page = splitted_chunk[5]
            bio = splitted_chunk[6:]   
        else:
            type_of_page = "Unknown"
            bio = "Unknown"
    except Exception as e:
        print(e)
        print(chunk)
    # print(username, no_of_posts, no_of_followers, no_of_following, name)

    # print(splitted_chunk[2].split(" followers")[0])
    # print(no_of_followers)

    return {"username": username, 
             "no_of_posts": no_of_posts,
             "no_of_followers": no_of_followers,
             "no_of_following": no_of_following,
             "name": name,
             "type_of_page": type_of_page,
             "bio": bio
           }

# %%
all_chunks = []
for chunk in chunks:
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)

# %%
import json

with open("finaldata.json", "w") as file:
    json.dump(all_chunks, file, indent=4)

# %%
with open("initialdata.json", "r") as file:
    data = json.load(file)

data
# Out:
# [{'username': 'intaglobal',
#   'no_of_posts': 1946,
#   'no_of_followers': 6851,
#   'no_of_following': 262,
#   'name': 'INTA',
#   'type_of_page': 'Nonprofit organization',
#   'bio': ['The association of ™ professionals.', 'inta.campsite.bio']},
#  {'username': '_anujsinghal',
#   'no_of_posts': 1785,
#   'no_of_followers': 681000,
#   'no_of_following': 248,
#   'name': 'Anuj Singhal',
#   'type_of_page': 'Digital creator',
#   'bio': ['Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India',
#    'Let’s talk about finance and life',
#    'Contact: Singhalanuj1010@gmail.com',
#    'hindi.cnbctv18.com/market-gurukul']},
#  {'username': 'code_flare',
#   'no_of_posts': 165,
#   'no_of_followers': 216,
#   'no_of_following': 10,
#   'name': 'The Journey Notebook | Travel | Food Blogger',
#   'type_of_page': 'Blogger',
#   'bio': ['📍 Exploring places & phases of life 🌍',
#    '.',
#    '🍵 From chai breaks to flight takes ✈️',
#    '.',
# ...

# %% [markdown]
# # Who has maximum posts
#
# Let's write the code to find out who has maximum number of posts

# %%
# find person with maximum Posts

max_post = 0
for chunk in all_chunks:
    if (max_post < chunk["no_of_posts"]):
        max_post = chunk["no_of_posts"]
        chunk_with_max_posts = chunk

print(chunk_with_max_posts)
# Out:
# {'username': 'startuphub_blr', 'no_of_posts': 2300, 'no_of_followers': 45000, 'no_of_following': 120, 'name': 'Startup Hub Bangalore', 'type_of_page': 'Media', 'bio': ['🦄 News from the Silicon Valley of India', '📢 Funding alerts, Hiring trends, and Drama', '📩 DM for features', 'startuphub.blr/newsletter']}

# %% [markdown]
# # Who has maximum followers
#
# Let's write the code to find out who has maximum number of followers

# %%
# find person with maximum followers

max_followers = 0
for chunk in all_chunks:
    if (max_followers < chunk["no_of_followers"]):
        max_followers = chunk["no_of_followers"]
        chunk_with_max_followers = chunk

print(chunk_with_max_followers)
# Out:
# {'username': '_anujsinghal', 'no_of_posts': 1785, 'no_of_followers': 681000, 'no_of_following': 248, 'name': 'Anuj Singhal', 'type_of_page': 'Digital creator', 'bio': ['Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India', 'Let’s talk about finance and life', 'Contact: Singhalanuj1010@gmail.com', 'hindi.cnbctv18.com/market-gurukul']}

# %% [markdown]
# # Who follows maximum people
#
# Let's write the code to find out who follows maximum number of people

# %%
# find person with maximum following

max_following = 0
for chunk in all_chunks:
    if (max_following < chunk["no_of_following"]):
        max_following = chunk["no_of_following"]
        chunk_with_max_following = chunk

print(chunk_with_max_following)
# Out:
# {'username': 'bangalore_tech_bro', 'no_of_posts': 402, 'no_of_followers': 12500, 'no_of_following': 890, 'name': 'Rahul | HSR Hustler', 'type_of_page': 'Entrepreneur', 'bio': ['🚀 Building the next Unicorn in Fintech', '☕ 3rd Wave Coffee addict', '💻 Python | React | AI', '📍 HSR Layout, BLR', 'linktr.ee/rahulbuilds']}

# %% [markdown]
# # Finding different types of Categories in our Data

# %%
categories = set()

for chunk in all_chunks:
    if chunk["type_of_page"] != "Unknown":
        categories.add(chunk["type_of_page"])

# %%
print(f"There are {len(categories)} different categories of people in our dataset, namely: ")
for category in categories:
    print("    - " + category)
# Out:
# There are 34 different categories of people in our dataset, namely:
#     - Tech Creator
#     - Nonprofit organization
#     - Public Figure
#     - Product Manager
#     - Food & Drink
#     - Design
#     - Education
#     - Community
#     - Software Engineer
#     - Writer
#     - Founder
#     - Comedy
#     - Recruiter
#     - Personal Blog
#     - Full-stack Dev
#     - Artist + Coder
#     - Data Science
#     - Blog
#     - Data Scientist
#     - Developer
#     - Backend Developer
#     - Engineer
#     - Lifestyle
#     - Cafe Nerd
#     - Educator
#     - Investor
#     - Tech
#     - Entrepreneur
#     - Cafe Explorer
#     - Digital creator
#     - Media
#     - Blogger
#     - Coder
#     - Frontend Dev
